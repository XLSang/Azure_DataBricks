# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Raw Data Generation

# %% [markdown]
# ## Notebook Objective
#
# In this notebook we:
# 1. Ingest data from a remote source into our source directory, `rawPath`.

# %% [markdown]
# ## Step Configuration
#
# Before you run this cell, make sure to add a unique user name to the file
# `includes/configuration`, e.g.
#
# ```
# username = "yourfirstname_yourlastname"
# ```

# %%
# %run ./includes/configuration

# %% [markdown]
# ## Utility Function
#
# Run the following command to load the utility function, `retrieve_data`.

# %%
# %run ./includes/utilities

# %% [markdown]
# ## Generate User Table
#
# Run the following cell to generate a User dimension table.

# %%
# %run ./includes/user

# %% [markdown]
# ## Make Notebook Idempotent

# %%
dbutils.fs.rm(classicPipelinePath, recurse=True)

# %% [markdown]
# ## Prepare Lab Data
#
# Run this cell to prepare the data we will use for this Lab.

# %%
prepare_activity_data(landingPath)

# %% [markdown]
# ## Ingestion function
# The `includes/utilities` file contains a function called `ingest_classic_data()`.
# We will use this function to ingest an hour of data at a time.
# This will simulate a Kafka feed.
#
# Run this function here to ingest the first hour of data.
#
# If successful, you should see the result, `True`.

# %%
ingest_classic_data()

# %% [markdown]
# ## Display the Raw Data Directory
# You should see that one file has landed in the Raw Data Directory.

# %%
display(dbutils.fs.ls(rawPath))

# %% [markdown]
# **EXERCISE:** Land five hours of data using the utility function,
# `ingest_classic_data`.
#
# 😎 **Note** the function can take a number of `hours` as an argument.

# %%
# ANSWER
ingest_classic_data(hours=5)

# %%
display(dbutils.fs.ls(rawPath))

# %% [markdown]
# ## Print the Contents of the Raw Files
# **EXERCISE**: Add the correct file paths to display the contents of the two raw files you loaded.

# %%
# ANSWER
print(
    dbutils.fs.head(
        dbutils.fs.ls("dbfs:/dbacademy/dbacademy/dataengineering/classic/raw/")[0].path
    )
)

# %%
# ANSWER
print(
    dbutils.fs.head(
        dbutils.fs.ls("dbfs:/dbacademy/dbacademy/dataengineering/classic/raw/")[1].path
    )
)

# %% [markdown]
# ## What do you notice about the data? (scroll down)

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
