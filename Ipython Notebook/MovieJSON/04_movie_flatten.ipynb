# %%
# %run "./movies_ingest_time"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
# ...

# %%
flatten_movie=new_movies.select("movies","SK","time").select("SK",
  "movies.Id",
  "movies.Title",
  "movies.Overview",
  "movies.Tagline",
  "movies.Budget",
  "movies.Revenue",
  "movies.ImdbUrl",
  "movies.PosterUrl",
  "movies.BackdropUrl",
  "movies.OriginalLanguage",
  "movies.ReleaseDate",
  "movies.RunTime",
  "movies.Price",
  "movies.CreatedDate",
  "movies.UpdatedDate",
  "movies.UpdatedBy",
  "movies.CreatedBy",
  "movies.genres",
  "time")
#display(flatten_movie)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
# ...

# %%
#convert string to timestamp, then convert to date type
movies_table2=flatten_movie.withColumn(("ReleaseDate"),to_date(unix_timestamp("ReleaseDate", "yyyy-MM-dd'T'HH:mm:ss").cast("timestamp")))
movies_table3=movies_table2.withColumn(("CreatedDate"),to_date(unix_timestamp("CreatedDate", "yyyy-MM-dd'T'HH:mm:ss.SSSSSSS").cast("timestamp")))
#Sorted_df = table3.orderBy(col("Id"))
#display(movies_table3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#movies_table3.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- SK: string (nullable = true)
# -- Id: long (nullable = true)
# -- Title: string (nullable = true)
# -- Overview: string (nullable = true)
# -- Tagline: string (nullable = true)
# -- Budget: double (nullable = true)
# -- Revenue: double (nullable = true)
# -- ImdbUrl: string (nullable = true)
# -- PosterUrl: string (nullable = true)
# -- BackdropUrl: string (nullable = true)
# -- OriginalLanguage: string (nullable = true)
# -- ReleaseDate: date (nullable = true)
# -- RunTime: long (nullable = true)
# -- Price: double (nullable = true)
# -- CreatedDate: date (nullable = true)
# -- UpdatedDate: string (nullable = true)
# ...

# %%
#from pyspark.sql.types import DateType

#flatten_movie.withColumn("ReleaseDate",col("ReleaseDate").cast(DateType()))
